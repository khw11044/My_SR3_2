# %%
from helpers import *
import helpers
import torch
from torch.utils.data import Dataset, DataLoader
import torchshow

# %%
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
root = './dataset'
ds = MySRDataset(root, hr_sz = 128, lr_sz = 32)
loader = DataLoader(ds, batch_size = 4, shuffle = True, drop_last = True, num_workers = 0)

# %%
# 학습용 이미지 뽑기

seed = 90 # np.random.randint(2147483647) 
random.seed(seed)
torch.manual_seed(seed)
        
dataiter = iter(loader)
lr_image, hr_image = next(dataiter)

# %%
lr_image, hr_image = next(dataiter)

# %%
lr_image.shape, hr_image.shape
# Out:
# (torch.Size([4, 3, 128, 128]), torch.Size([4, 3, 128, 128]))

# %%
torchshow.show(lr_image)

# %%
torchshow.show(hr_image)

# %%
seed = np.random.randint(2147483647)
print(seed)
# Out:
# 320018009
